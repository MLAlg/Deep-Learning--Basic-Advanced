# %%
from keras import regularizers
from keras.layers import Input, Dense
from keras.models import Model

encoding_dim = 32

input_img = Input(shape=(784,))
# add a Dense layer with a L1 activity regularizer
encoded = Dense(encoding_dim, activation='relu',
                activity_regularizer=regularizers.l1(10e-5))(input_img)
decoded = Dense(784, activation='sigmoid')(encoded)

autoencoder = Model(input_img, decoded)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# create a separate encoder model:

# %%
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# %% [markdown]
# the decoder model:

# %%
# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

# %% [markdown]
# we'll configure our model to use a per-pixel binary crossentropy loss, and the Adadelta optimizer:

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %% [markdown]
# We're using MNIST digits, and we're discarding the labels

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

# %% [markdown]
# We will normalize all values between 0 and 1 and we will flatten the 28x28 images into vectors of size 784.

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# train our autoencoder for 5 epochs:

# %%
autoencoder.fit(x_train, x_train,
                epochs=5,
                batch_size=32,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.3278 - val_loss: 0.3186
# Epoch 2/5
# 60000/60000 [==============================] - 6s 101us/step - loss: 0.3117 - val_loss: 0.3061
# Epoch 3/5
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.3015 - val_loss: 0.2978
# Epoch 4/5
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.2946 - val_loss: 0.2919
# Epoch 5/5
# 60000/60000 [==============================] - 6s 105us/step - loss: 0.2896 - val_loss: 0.2876
